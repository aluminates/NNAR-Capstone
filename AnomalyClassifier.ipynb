# %%
# !pip install import_ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import import_ipynb

# %%
import TextFeature

# %%
text="""The video captures a chaotic scene unfolding on a rainy night in India. The setting is outdoors on the side of a busy road, where a group of young men and women are gathered around a white car. The surroundings are marked by the wet pavement and the presence of other vehicles passing by. Some individuals are lying on the ground, while others are standing or sitting near the car.
Suddenly, a group of police officers arrives at the scene and begins questioning the group. The situation quickly escalates as the police start physically removing people from the area, leading to a scuffle. One person is seen being pushed into the back of a police vehicle. Throughout the video, there is a sense of confusion and tension between the police and the young people. The rain adds to the chaotic atmosphere, making the scene even more dramatic."""

# %%
text_embedding=TextFeature.generate_text_embedding(text)

# %%
if text_embedding is not None:
    print("Embedding Generation of the Caption Successful")
else:
    print("Embedding Generation of the Caption Failed")
# Out:
# Embedding Generation of the Caption Successful

# %%
import VideoFeature

# %%
video_path = '/content/drive/MyDrive/Integration/v088_converted (1).mp4'

# %%
video_embedding = VideoFeature.generate_representation(video_path)

# %%
if video_embedding is not None:
    print("Embedding Generation of the Video Successful")
else:
    print("Embedding Generation of the Video Failed")
# Out:
# Embedding Generation of the Video Successful
